# %% [markdown]
# <a href="https://colab.research.google.com/github/orion-alpha-kplr/KPLR-PROJET-CASSANDRA/blob/main/Exercice/4_Scrape_Car_Attributs_Using_Requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Récupérer les attributs d'une voiture à l'aide de Requests**

# %% [markdown]
# - Nous allons extraire des données des sites web d'un concessionnaire automobile : nous allons extraire - la marque - le modèle - le type de carburant - les kilomètres - l'année du modèle - le prix.

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/123748165/224308731-cb43fb4b-69f9-4d5d-b52f-1d2b157aaae5.png)

# %% [markdown]
# #### 1 - Imports

# %%
import requests 
import pandas as pd 
import sqlalchemy
import json

# %% [markdown]
# #### 2 - CURL

# %% [markdown]
# **Comment afficher les en-têtes HTTP ? [Y compris les cookies]**

# %% [markdown]
# - Avant de pouvoir utiliser les en-têtes dans notre code, nous devons être en mesure de les récupérer quelque part. Pour ce faire, utilisons notre propre navigateur et allons sur le site web cible.
# - Pour notre exemple, allons sur https://www.cazoo.co.uk/cars/?page=2 > clic droit > inspecter pour ouvrir les outils de développement.

# %% [markdown]
# - nous allons naviguer dans l'onglet Réseau et rechercher la requête "?page 2".

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/123748165/224308744-61c1ed97-1680-47bf-a531-0f0daa24f5ce.png)

# %% [markdown]
# - En cliquant sur le fichier, nous ouvrirons par défaut l'onglet En-têtes et en faisant défiler vers le bas, nous verrons la section En-têtes de la request.

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/123748165/224308758-b28b3301-4f75-42ac-a682-953790c4405c.png)

# %% [markdown]
# ***Headers Arguments***

# %% [markdown]
# - **User-Agent** : Il s'agit probablement de l'en-tête le plus important, car il identifie "le type d'application, le système d'exploitation, le fournisseur du logiciel ou la version du logiciel de l'agent utilisateur demandeur".
# le fournisseur du logiciel ou la version logicielle de l'agent utilisateur du logiciel demandeur", ce qui en fait le premier contrôle effectué par la plupart des serveurs.
#
# - **Accept-Language** : Bien qu'elle ne soit pas toujours nécessaire, cette fonction indique au serveur la version linguistique des données à fournir. Lorsqu'il y a une grande différence entre chaque demande du point de vue de la langue, cela peut indiquer au serveur qu'un robot est impliqué.
#
# - **Referer** : L'en-tête HTTP Referer indique au serveur la page d'où provient l'utilisateur. Bien qu'il soit principalement utilisé pour le suivi, il peut également nous aider à imiter le comportement d'un utilisateur organique, par exemple en indiquant au serveur que nous venons d'un moteur de recherche comme Google.
#
# - **Cookie** : Les cookies permettent aux serveurs de communiquer à l'aide d'un petit morceau de données, mais que se passe-t-il lorsque le serveur envoie un cookie mais que le navigateur ne le stocke pas et ne le renvoie pas lors de la requête suivante ? Les cookies peuvent également être utilisés pour identifier si la demande provient d'un utilisateur réel ou d'un robot.
# - **sec-fetch-site** : cet en-tête indique au serveur si une demande de ressource provient de la même origine, du même site, d'un site différent ou s'il s'agit d'une demande "initiée par l'utilisateur". Le serveur peut alors utiliser cette information pour décider si la demande doit être autorisée.
# - **sec-fetch-mode** : permet à un serveur de faire la distinction entre : les demandes provenant d'un utilisateur naviguant entre des pages HTML, et les demandes de chargement d'images et d'autres ressources. Par exemple, cet en-tête contiendrait navigate pour les demandes de navigation de haut niveau, tandis que no-cors serait utilisé pour le chargement d'une image.
#
# - **sec-fetch-Dest** : permet aux serveurs de déterminer s'ils doivent répondre à une demande en fonction de son utilisation prévue.

# %%
headers = {
    'authority': 'www.cazoo.co.uk',
    'sec-ch-ua': '^\\^',
    'cazoo-language': 'en',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'cazoo-market': 'gb',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.cazoo.co.uk/cars/?page=2',
    'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
    'cookie': 'base_device_id=d0a0a3f4-6853-469a-920f-6050e04a23d0; base_session_count=1; base_session_id=aa7da8a1-20b0-44f4-b994-7b19b379af45',
}

params = (
    ('sort', 'price-asc'),
)

response = requests.get('https://www.cazoo.co.uk/api/search', headers=headers, params=params)

# %% [markdown]
# 3 - Check Status Code

# %% [markdown]
# - Vérifier en ligne de commande l'état de la réponse

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### 4 - Créer un objet Json

# %% [markdown]
# - Créer un objet json à partir de la réponse

# %%
#@title Titre par défaut
results_json = json.loads(response.text)
results_json

# %% [markdown]
# #### 5 - Output Keys

# %% [markdown]
# - Sortie des clés de notre fichier results_json

# %%
#dict_keys(['results', 'filters', 'pagination'])
dict_keys =results_json.keys()
print(dict_keys)
# Out:
# dict_keys(['results', 'filters', 'pagination'])

# %%
listing = results_json['results']
listing
# Out:
# [{'createdAt': '2022-11-08T08:38:09.112Z',
#   'id': 'd70f47aa-7575-550c-99f5-9be578268782',
#   'make': 'Kia',
#   'makeIdentifier': 'kia',
#   'model': 'Picanto',
#   'modelIdentifier': 'picanto',
#   'modelYear': 2015,
#   'displayVariant': '1.0 SR7',
#   'mileage': 36057,
#   'registrationYear': 2016,
#   'vrm': 'DF16YTA',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/KNABX311LGT188402/402fe397-dd90-4d98-b5e8-516130dfcda1.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 36057},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/KNABX311LGT188402/402fe397-dd90-4d98-b5e8-516130dfcda1.jpg',
#     'car_gallery_images/KNABX311LGT188402/927be04f-f183-499b-82ed-bfb632c25fdc.jpg',
#     'car_gallery_images/KNABX311LGT188402/2e82ef9d-8be6-436d-b1d1-e8259ec87612.jpg',
#     'car_gallery_images/KNABX311LGT188402/f474d8d2-3f25-48d7-8d00-25e096840c8c.jpg',
#     'car_gallery_images/KNABX311LGT188402/b67a3d48-9115-4b39-81e4-9fc062f6da67.jpg',
#     'car_gallery_images/KNABX311LGT188402/kez0rT1zXLRsBPe6NP9O.JPG',
#     'car_gallery_images/KNABX311LGT188402/96FuM6xyvIaovnqRIVsl.JPG',
#     'car_gallery_images/KNABX311LGT188402/yqCA2C9mLTRnAFosnbQc.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 655000,
#     'currencyCode': 'GBP',
#     'value': 6550},
#    'pcmPrice': {'hp': {'centAmount': 11610,
#      'currencyCode': 'GBP',
#      'value': 116},
#     'lowest': {'centAmount': 11610,
#      'currencyCode': 'GBP',
#      'value': 116,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-02-17T09:47:03.225Z',
#   'id': '2e2e7843-5e3b-5c4a-83ad-9f43c3d15eb9',
#   'make': 'Peugeot',
#   'makeIdentifier': 'peugeot',
#   'model': '108',
#   'modelIdentifier': '108',
#   'modelYear': 2016,
#   'displayVariant': '1.0 Active',
#   'mileage': 35847,
#   'registrationYear': 2016,
#   'vrm': 'CE66OUX',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF3PSCFBCGR105271/507feb96-0e35-42e9-a6d8-21367e1bf475.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 35847},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF3PSCFBCGR105271/507feb96-0e35-42e9-a6d8-21367e1bf475.jpg',
#     'car_gallery_images/VF3PSCFBCGR105271/626ee8f0-08e2-4774-9b27-2165f15f3848.jpg',
#     'car_gallery_images/VF3PSCFBCGR105271/b320d7f5-f3ec-474b-9617-70fd10b47136.jpg',
#     'car_gallery_images/VF3PSCFBCGR105271/05c9d7bf-b926-4681-8477-c587ee276e8c.jpg',
#     'car_gallery_images/VF3PSCFBCGR105271/9159d80c-165b-4962-9f42-6f260bc7bf5e.jpg',
#     'car_gallery_images/VF3PSCFBCGR105271/tEzpQJZSJKv2YuA0PkyM.JPG',
#     'car_gallery_images/VF3PSCFBCGR105271/5gZgAAMQfxUjPkBKHrfo.JPG',
#     'car_gallery_images/VF3PSCFBCGR105271/5REhNOlf0y3xPMDowbmd.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 680000,
#     'currencyCode': 'GBP',
#     'value': 6800},
#    'pcmPrice': {'hp': {'centAmount': 12248,
#      'currencyCode': 'GBP',
#      'value': 122},
#     'lowest': {'centAmount': 12248,
#      'currencyCode': 'GBP',
#      'value': 122,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-25T16:50:01.035Z',
#   'id': 'd0c5ee4e-3037-5a98-a246-be89c27ba154',
#   'make': 'Peugeot',
#   'makeIdentifier': 'peugeot',
#   'model': '108',
#   'modelIdentifier': '108',
#   'modelYear': 2016,
#   'displayVariant': '1.2 PureTech Allure',
#   'mileage': 62681,
#   'registrationYear': 2016,
#   'vrm': 'CJ02PEG',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF3PAHMTCGR290128/e9fb101c-bc9f-4438-9647-143afefe0794.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 62681},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF3PAHMTCGR290128/e9fb101c-bc9f-4438-9647-143afefe0794.jpg',
#     'car_gallery_images/VF3PAHMTCGR290128/ad46173c-687d-49a7-901e-550016bb4a9c.jpg',
#     'car_gallery_images/VF3PAHMTCGR290128/425e8cec-dad0-4c73-9c4d-4960bc0d01e6.jpg',
#     'car_gallery_images/VF3PAHMTCGR290128/5af23d14-7585-48d0-a595-1e7b5a11b12b.jpg',
#     'car_gallery_images/VF3PAHMTCGR290128/75d01144-2e43-4357-8302-c01004b3ae65.jpg',
#     'car_gallery_images/VF3PAHMTCGR290128/D9zUm4akdMDR0l9LJwiY.JPG',
#     'car_gallery_images/VF3PAHMTCGR290128/M1Pqybk83rPR6WQZmPLZ.JPG',
#     'car_gallery_images/VF3PAHMTCGR290128/e7suVF8TgJ9lKKatS6xn.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 690000,
#     'currencyCode': 'GBP',
#     'value': 6900},
#    'pcmPrice': {'hp': {'centAmount': 12503,
#      'currencyCode': 'GBP',
#      'value': 125},
#     'lowest': {'centAmount': 12503,
#      'currencyCode': 'GBP',
#      'value': 125,
#      'type': 'hp'}}},
#   'isLocked': True},
#  {'createdAt': '2022-11-29T08:34:17.695Z',
#   'id': 'e30528a4-3ed7-56c4-ac82-73ddb29c67d0',
#   'make': 'Peugeot',
#   'makeIdentifier': 'peugeot',
#   'model': '108',
#   'modelIdentifier': '108',
#   'modelYear': 2015,
#   'displayVariant': '1.0 Active Top!',
#   'mileage': 43773,
#   'registrationYear': 2015,
#   'vrm': 'YA65FJC',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF3PSCFBCFR074187/90f9b7e6-305c-4efe-b7a0-152ebb0a7089.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 43773},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF3PSCFBCFR074187/90f9b7e6-305c-4efe-b7a0-152ebb0a7089.jpg',
#     'car_gallery_images/VF3PSCFBCFR074187/c1f835ef-659c-49b4-9712-616dfd463b41.jpg',
#     'car_gallery_images/VF3PSCFBCFR074187/556a4a35-9327-4c93-bed6-9f8c6796d411.jpg',
#     'car_gallery_images/VF3PSCFBCFR074187/d0946f1a-546d-490f-af10-a5021b23a757.jpg',
#     'car_gallery_images/VF3PSCFBCFR074187/bc5f4ebd-b094-4d0c-8469-4aabd52517ef.jpg',
#     'car_gallery_images/VF3PSCFBCFR074187/0RPpaD1Q2YbBAuBhR4dX.JPG',
#     'car_gallery_images/VF3PSCFBCFR074187/aiY9U0wESOsJondfK7na.JPG',
#     'car_gallery_images/VF3PSCFBCFR074187/2L87kXT8pjrizp765LA9.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 690000,
#     'currencyCode': 'GBP',
#     'value': 6900},
#    'pcmPrice': {'hp': {'centAmount': 12503,
#      'currencyCode': 'GBP',
#      'value': 125},
#     'lowest': {'centAmount': 12503,
#      'currencyCode': 'GBP',
#      'value': 125,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2022-05-29T16:17:02.883Z',
#   'id': '17e063b4-f805-543b-a47d-5a9c130bbdd5',
#   'make': 'Fiat',
#   'makeIdentifier': 'fiat',
#   'model': '500',
#   'modelIdentifier': '500',
#   'modelYear': 2015,
#   'displayVariant': '1.2 Lounge',
#   'mileage': 41216,
#   'registrationYear': 2015,
#   'vrm': 'EU65UCG',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/ZFA3120000J462540/d0d5fac0-eb07-44df-933d-e65a40e2e802.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 41216},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/ZFA3120000J462540/d0d5fac0-eb07-44df-933d-e65a40e2e802.jpg',
#     'car_gallery_images/ZFA3120000J462540/6b0e6c77-e8ec-4de3-b664-11563deefe94.jpg',
#     'car_gallery_images/ZFA3120000J462540/a8c21bb2-d6f7-48d7-80d5-4b8ff41df99e.jpg',
#     'car_gallery_images/ZFA3120000J462540/e81ea37a-c817-46f1-97bd-d6f8c92cf92c.jpg',
#     'car_gallery_images/ZFA3120000J462540/595e1419-805c-4d9b-a762-9aa2064baf89.jpg',
#     'car_gallery_images/ZFA3120000J462540/xvOqRs91zvGcvcZjnSKG.JPG',
#     'car_gallery_images/ZFA3120000J462540/SgTFyKIltiwxxvb61y6S.JPG',
#     'car_gallery_images/ZFA3120000J462540/Kev7PrvFClNsDX6eOTOl.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 700000,
#     'currencyCode': 'GBP',
#     'value': 7000},
#    'pcmPrice': {'hp': {'centAmount': 12763,
#      'currencyCode': 'GBP',
#      'value': 128},
#     'lowest': {'centAmount': 12763,
#      'currencyCode': 'GBP',
#      'value': 128,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-02-24T01:14:05.248Z',
#   'id': '97132e33-761a-523c-b69e-fc3529d8ed8a',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'Corsa',
#   'modelIdentifier': 'corsa',
#   'modelYear': 2017,
#   'displayVariant': '1.4i ecoFLEX Sting',
#   'mileage': 30278,
#   'registrationYear': 2016,
#   'vrm': 'PY16KXL',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0L0XEP08G6105477/842ac244-8a38-4d08-987d-08e79152ed35.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 30278},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0L0XEP08G6105477/842ac244-8a38-4d08-987d-08e79152ed35.jpg',
#     'car_gallery_images/W0L0XEP08G6105477/93e442fc-8c70-48ba-98ff-75d1595bf488.jpg',
#     'car_gallery_images/W0L0XEP08G6105477/98c00950-2705-4281-9d69-d0e3d87e5f51.jpg',
#     'car_gallery_images/W0L0XEP08G6105477/8a1bdbb4-6faf-438a-8d4e-431531ca0509.jpg',
#     'car_gallery_images/W0L0XEP08G6105477/8921e16d-1036-408f-ad4f-2832434d1edb.jpg',
#     'car_gallery_images/W0L0XEP08G6105477/AHWyMTet3hpAnAWFZzaN.JPG',
#     'car_gallery_images/W0L0XEP08G6105477/OAgDqAl5cyHThyYMblpL.JPG',
#     'car_gallery_images/W0L0XEP08G6105477/ESxpDWZV3BY2w8nG5j5q.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 720000,
#     'currencyCode': 'GBP',
#     'value': 7200},
#    'pcmPrice': {'hp': {'centAmount': 13273,
#      'currencyCode': 'GBP',
#      'value': 133},
#     'lowest': {'centAmount': 13273,
#      'currencyCode': 'GBP',
#      'value': 133,
#      'type': 'hp'}}},
#   'isLocked': True},
#  {'createdAt': '2023-01-16T08:50:40.933Z',
#   'id': '38b03767-fc1f-5d0a-a4aa-60fe4d300983',
#   'make': 'Fiat',
#   'makeIdentifier': 'fiat',
#   'model': '500',
#   'modelIdentifier': '500',
#   'modelYear': 2015,
#   'displayVariant': '1.2 Lounge',
#   'mileage': 35534,
#   'registrationYear': 2016,
#   'vrm': 'LC16MLV',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/ZFA3120000J601914/dc15c69a-0dad-4936-94bd-0dd4738c4bb4.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 35534},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/ZFA3120000J601914/dc15c69a-0dad-4936-94bd-0dd4738c4bb4.jpg',
#     'car_gallery_images/ZFA3120000J601914/1900d47f-4131-4080-97b6-940e0f455587.jpg',
#     'car_gallery_images/ZFA3120000J601914/33875d71-95cb-4615-a2e8-6ada5d2f0fb6.jpg',
#     'car_gallery_images/ZFA3120000J601914/59578bd0-ad30-4714-9517-aff1d8d1fcf9.jpg',
#     'car_gallery_images/ZFA3120000J601914/23a184fa-fa93-484f-9fe4-d5a5df1396bd.jpg',
#     'car_gallery_images/ZFA3120000J601914/8zhz3wFCYFK2IvEa1EcW.JPG',
#     'car_gallery_images/ZFA3120000J601914/HahJZUXv2LhJNUXGnnZq.JPG',
#     'car_gallery_images/ZFA3120000J601914/BsQthcdyABvbKRBRbaRe.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 740000,
#     'currencyCode': 'GBP',
#     'value': 7400},
#    'pcmPrice': {'hp': {'centAmount': 13784,
#      'currencyCode': 'GBP',
#      'value': 138},
#     'lowest': {'centAmount': 13784,
#      'currencyCode': 'GBP',
#      'value': 138,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2022-11-29T16:47:47.019Z',
#   'id': '89eb4729-bc49-5b96-95e6-ca953d09a8e3',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'Corsa',
#   'modelIdentifier': 'corsa',
#   'modelYear': 2016,
#   'displayVariant': '1.4i ecoFLEX Energy (a/c)',
#   'mileage': 54681,
#   'registrationYear': 2016,
#   'vrm': 'KY66HNV',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0L0XEP08G6089483/9cec85a8-45ff-43fb-b64b-d230307c3c45.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 54681},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0L0XEP08G6089483/9cec85a8-45ff-43fb-b64b-d230307c3c45.jpg',
#     'car_gallery_images/W0L0XEP08G6089483/06babaff-d8d7-4552-8589-68218c6114ea.jpg',
#     'car_gallery_images/W0L0XEP08G6089483/0f91fa94-f0c9-45c7-b9a6-2f5b46c89d42.jpg',
#     'car_gallery_images/W0L0XEP08G6089483/1312dca4-ca9e-45ae-a4e9-c00ddc253fdd.jpg',
#     'car_gallery_images/W0L0XEP08G6089483/eea70cfb-b0e5-416a-8886-289189665a11.jpg',
#     'car_gallery_images/W0L0XEP08G6089483/GtYvt6PzaBiTMgDKsEx0.JPG',
#     'car_gallery_images/W0L0XEP08G6089483/T52fb2lpLIDJ1tHx3zgH.JPG',
#     'car_gallery_images/W0L0XEP08G6089483/dZ7WCKIJMEaRY1iX3xzb.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 740000,
#     'currencyCode': 'GBP',
#     'value': 7400},
#    'pcmPrice': {'hp': {'centAmount': 13784,
#      'currencyCode': 'GBP',
#      'value': 138},
#     'lowest': {'centAmount': 13784,
#      'currencyCode': 'GBP',
#      'value': 138,
#      'type': 'hp'}}},
#   'isLocked': True},
#  {'createdAt': '2022-10-21T18:32:04.915Z',
#   'id': '6e784917-a553-503b-9f8c-fc6584af1df7',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'ADAM',
#   'modelIdentifier': 'adam',
#   'modelYear': 2017,
#   'displayVariant': '1.2i ecoFLEX ENERGISED',
#   'mileage': 36676,
#   'registrationYear': 2016,
#   'vrm': 'BL66KYC',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0L0MAP08H6020896/502f8369-591c-4e12-9e9f-8beb6fb98ed2.jpg'}},
#   'isPromoted': True,
#   'odometerReading': {'unit': 'mile', 'value': 36676},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0L0MAP08H6020896/502f8369-591c-4e12-9e9f-8beb6fb98ed2.jpg',
#     'car_gallery_images/W0L0MAP08H6020896/01b3e3dd-1dac-4754-b802-06f73e821a05.jpg',
#     'car_gallery_images/W0L0MAP08H6020896/588fd4e1-d719-4dfc-9445-83269149df78.jpg',
#     'car_gallery_images/W0L0MAP08H6020896/cd696e99-c394-4d30-a66a-7815cb6000ec.jpg',
#     'car_gallery_images/W0L0MAP08H6020896/6b49701b-aac1-41c7-ab67-9304e17296f3.jpg',
#     'car_gallery_images/W0L0MAP08H6020896/iojHwYH7BGlw2JA8UfwM.JPG',
#     'car_gallery_images/W0L0MAP08H6020896/prWQ9BVfXhfXLhw29kO9.JPG',
#     'car_gallery_images/W0L0MAP08H6020896/moBJiYsM2jDW4jLkZqHl.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 740000,
#     'currencyCode': 'GBP',
#     'value': 7400},
#    'priceBeforePromotion': {'centAmount': 755000,
#     'currencyCode': 'GBP',
#     'value': 7550},
#    'pcmPrice': {'hp': {'centAmount': 13784,
#      'currencyCode': 'GBP',
#      'value': 138},
#     'lowest': {'centAmount': 13784,
#      'currencyCode': 'GBP',
#      'value': 138,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-17T17:12:55.109Z',
#   'id': '569d47d1-2b01-508c-ad7b-5a054f4463c7',
#   'make': 'Toyota',
#   'makeIdentifier': 'toyota',
#   'model': 'AYGO',
#   'modelIdentifier': 'aygo',
#   'modelYear': 2017,
#   'displayVariant': '1.0 VVT-i x-play',
#   'mileage': 56845,
#   'registrationYear': 2017,
#   'vrm': 'FP17KHC',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/JTDKGNEC40N250896/bd0516b9-8558-41a9-8cb6-d3422fe0239d.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 56845},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/JTDKGNEC40N250896/bd0516b9-8558-41a9-8cb6-d3422fe0239d.jpg',
#     'car_gallery_images/JTDKGNEC40N250896/8ba94f1c-558b-4855-bdda-a2f421ba0c49.jpg',
#     'car_gallery_images/JTDKGNEC40N250896/afcfd335-f405-4747-85a3-4e6b639e7ac1.jpg',
#     'car_gallery_images/JTDKGNEC40N250896/ba85df0f-039a-4ed3-a839-548e6cb035c1.jpg',
#     'car_gallery_images/JTDKGNEC40N250896/79d57bfe-5557-4a77-8427-ace94dac605e.jpg',
#     'car_gallery_images/JTDKGNEC40N250896/XrQZ2E8LWUY65AAyRBVI.JPG',
#     'car_gallery_images/JTDKGNEC40N250896/7269wJsGPoJxvJChyaO7.JPG',
#     'car_gallery_images/JTDKGNEC40N250896/WgyESGa1DnnpovAG3q8Z.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 745000,
#     'currencyCode': 'GBP',
#     'value': 7450},
#    'pcmPrice': {'hp': {'centAmount': 13911,
#      'currencyCode': 'GBP',
#      'value': 139},
#     'lowest': {'centAmount': 13911,
#      'currencyCode': 'GBP',
#      'value': 139,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-01-16T18:54:04.225Z',
#   'id': '8ddcc1c4-a215-53d1-9024-ba83a8ba34c4',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'Viva',
#   'modelIdentifier': 'viva',
#   'modelYear': 2017,
#   'displayVariant': '1.0i SE',
#   'mileage': 9664,
#   'registrationYear': 2016,
#   'vrm': 'LV66NMJ',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0LDD6E76GC641143/8e2671ce-bc73-404b-976d-b806e240902f.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 9664},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0LDD6E76GC641143/8e2671ce-bc73-404b-976d-b806e240902f.jpg',
#     'car_gallery_images/W0LDD6E76GC641143/6f87b747-9b30-4a14-877e-db6e32475111.jpg',
#     'car_gallery_images/W0LDD6E76GC641143/4527c42d-6253-4233-982f-71581d7afe43.jpg',
#     'car_gallery_images/W0LDD6E76GC641143/f0b97775-d255-4591-b60d-9224eb05a087.jpg',
#     'car_gallery_images/W0LDD6E76GC641143/2c9265de-b77f-4876-abd5-e481d79d1c13.jpg',
#     'car_gallery_images/W0LDD6E76GC641143/63aERssvE1X036Olm9CE.JPG',
#     'car_gallery_images/W0LDD6E76GC641143/lcWp1pVwLqSdN0B9LFrK.JPG',
#     'car_gallery_images/W0LDD6E76GC641143/edzH4QB5CWWjyosj7igo.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 745000,
#     'currencyCode': 'GBP',
#     'value': 7450},
#    'pcmPrice': {'hp': {'centAmount': 13911,
#      'currencyCode': 'GBP',
#      'value': 139},
#     'lowest': {'centAmount': 13911,
#      'currencyCode': 'GBP',
#      'value': 139,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-13T11:16:59.009Z',
#   'id': '5aad832d-3928-58e9-ae7d-c6b4511e0c23',
#   'make': 'DS',
#   'makeIdentifier': 'ds',
#   'model': 'DS 3',
#   'modelIdentifier': 'ds-3',
#   'modelYear': 2015,
#   'displayVariant': '1.6 BlueHDi DStyle Nav',
#   'mileage': 54023,
#   'registrationYear': 2015,
#   'vrm': 'BL65DXJ',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Diesel',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF7SABHY6FW648927/27ce5d92-c562-41ec-9089-f347f3a95722.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 54023},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF7SABHY6FW648927/27ce5d92-c562-41ec-9089-f347f3a95722.jpg',
#     'car_gallery_images/VF7SABHY6FW648927/802e0b50-0895-454d-8625-e0afb9944b4f.jpg',
#     'car_gallery_images/VF7SABHY6FW648927/811725ef-f9dc-4872-9313-5b9999affbbd.jpg',
#     'car_gallery_images/VF7SABHY6FW648927/8f4af5e1-da67-45f4-960b-cbc9dc489348.jpg',
#     'car_gallery_images/VF7SABHY6FW648927/b7a05f7d-25f6-425c-b872-b9b65d8dee65.jpg',
#     'car_gallery_images/VF7SABHY6FW648927/zirJmFf6ixhs6uKpxZDE.JPG',
#     'car_gallery_images/VF7SABHY6FW648927/9CCwsGxagyHE9v9bTGK0.JPG',
#     'car_gallery_images/VF7SABHY6FW648927/EBuG56QDefEfkqMq2pKB.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 755000,
#     'currencyCode': 'GBP',
#     'value': 7550},
#    'pcmPrice': {'hp': {'centAmount': 14166,
#      'currencyCode': 'GBP',
#      'value': 142},
#     'lowest': {'centAmount': 14166,
#      'currencyCode': 'GBP',
#      'value': 142,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-10T09:46:50.323Z',
#   'id': '40982c5e-a985-57f7-ad1e-fcf3befaa883',
#   'make': 'Toyota',
#   'makeIdentifier': 'toyota',
#   'model': 'AYGO',
#   'modelIdentifier': 'aygo',
#   'modelYear': 2016,
#   'displayVariant': '1.0 VVT-i x-play',
#   'mileage': 32725,
#   'registrationYear': 2016,
#   'vrm': 'GF66MRO',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/JTDJGNEC40N189495/cda688b4-c7a8-476d-b504-04c4ca3d68c6.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 32725},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/JTDJGNEC40N189495/cda688b4-c7a8-476d-b504-04c4ca3d68c6.jpg',
#     'car_gallery_images/JTDJGNEC40N189495/225bb69d-a062-40b2-a9f2-0de728d2f1f0.jpg',
#     'car_gallery_images/JTDJGNEC40N189495/dfa5270c-9afd-4191-b0d5-adb2a5fbe3c1.jpg',
#     'car_gallery_images/JTDJGNEC40N189495/b20e94f8-9ecd-41a5-9e69-72d3e7965cc2.jpg',
#     'car_gallery_images/JTDJGNEC40N189495/b40ba9ca-11a2-4c15-b59f-02a14ba77e33.jpg',
#     'car_gallery_images/JTDJGNEC40N189495/AzBQYOspx9Yu5RY35o99.JPG',
#     'car_gallery_images/JTDJGNEC40N189495/K9xyZ8NnZ7AXYeA7BMWX.JPG',
#     'car_gallery_images/JTDJGNEC40N189495/OvmZbEnUClTSd7Ad4hOx.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 765000,
#     'currencyCode': 'GBP',
#     'value': 7650},
#    'pcmPrice': {'hp': {'centAmount': 14422,
#      'currencyCode': 'GBP',
#      'value': 144},
#     'lowest': {'centAmount': 14422,
#      'currencyCode': 'GBP',
#      'value': 144,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-01-06T03:48:08.172Z',
#   'id': '53ac4f09-e1eb-51c7-a391-1c9b6c697ade',
#   'make': 'Skoda',
#   'makeIdentifier': 'skoda',
#   'model': 'Citigo',
#   'modelIdentifier': 'citigo',
#   'modelYear': 2018,
#   'displayVariant': '1.0 MPI Colour Edition',
#   'mileage': 25428,
#   'registrationYear': 2017,
#   'vrm': 'GD17LXJ',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/TMBZZZAAZHD621240/dc8d1c4a-aaed-45b2-a2eb-bf2cfd90bfae.jpg'}},
#   'isPromoted': True,
#   'odometerReading': {'unit': 'mile', 'value': 25428},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/TMBZZZAAZHD621240/dc8d1c4a-aaed-45b2-a2eb-bf2cfd90bfae.jpg',
#     'car_gallery_images/TMBZZZAAZHD621240/d746a420-23d4-4637-975e-447ef550601b.jpg',
#     'car_gallery_images/TMBZZZAAZHD621240/fcfa89a0-c6f1-4aa6-9664-33d825a60ee1.jpg',
#     'car_gallery_images/TMBZZZAAZHD621240/48efc374-e49b-4aa0-ac14-73bc0e67772e.jpg',
#     'car_gallery_images/TMBZZZAAZHD621240/10acd5d9-570a-4218-8c58-eb8919a611ef.jpg',
#     'car_gallery_images/TMBZZZAAZHD621240/Ldl7nM8jKc1cJzegsOaw.JPG',
#     'car_gallery_images/TMBZZZAAZHD621240/nnHiHyDqeZYOk0sV5ZFe.JPG',
#     'car_gallery_images/TMBZZZAAZHD621240/8YUF0NY3OwZAHtDrkTyN.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 765000,
#     'currencyCode': 'GBP',
#     'value': 7650},
#    'priceBeforePromotion': {'centAmount': 780000,
#     'currencyCode': 'GBP',
#     'value': 7800},
#    'pcmPrice': {'hp': {'centAmount': 14422,
#      'currencyCode': 'GBP',
#      'value': 144},
#     'lowest': {'centAmount': 14422,
#      'currencyCode': 'GBP',
#      'value': 144,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-15T08:15:02.863Z',
#   'id': '55698fc7-b01b-5dd8-a909-1e5fcab6ac61',
#   'make': 'Dacia',
#   'makeIdentifier': 'dacia',
#   'model': 'Sandero',
#   'modelIdentifier': 'sandero',
#   'modelYear': 2017,
#   'displayVariant': '1.0 SCe Ambiance',
#   'mileage': 24080,
#   'registrationYear': 2018,
#   'vrm': 'WV18RWN',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/UU15SDMC560202321/3c7a9fb3-9a67-41c3-a0ea-20644bab49e9.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 24080},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/UU15SDMC560202321/3c7a9fb3-9a67-41c3-a0ea-20644bab49e9.jpg',
#     'car_gallery_images/UU15SDMC560202321/3695421d-2a45-4129-bed8-286e095dd61f.jpg',
#     'car_gallery_images/UU15SDMC560202321/989b1bfb-faf8-48eb-95c3-147406425da4.jpg',
#     'car_gallery_images/UU15SDMC560202321/b75d8cb2-ce83-492c-8f75-d5add2f3e335.jpg',
#     'car_gallery_images/UU15SDMC560202321/8b84cb89-da34-41e5-871c-db0fd733be7b.jpg',
#     'car_gallery_images/UU15SDMC560202321/JtSYRkgoiGffl2ntfdX4.JPG',
#     'car_gallery_images/UU15SDMC560202321/mj06sIgVlqoHuSgNF07y.JPG',
#     'car_gallery_images/UU15SDMC560202321/FcdMtq06CVF8HoU87Rgq.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 770000,
#     'currencyCode': 'GBP',
#     'value': 7700},
#    'pcmPrice': {'pcp': {'centAmount': 11044,
#      'currencyCode': 'GBP',
#      'value': 110},
#     'hp': {'centAmount': 14549, 'currencyCode': 'GBP', 'value': 145},
#     'lowest': {'centAmount': 11044,
#      'currencyCode': 'GBP',
#      'value': 110,
#      'type': 'pcp'}}},
#   'isLocked': False},
#  {'createdAt': '2022-10-31T13:42:42.911Z',
#   'id': 'ba1a6d48-c461-58a0-af71-327781eae73d',
#   'make': 'Fiat',
#   'makeIdentifier': 'fiat',
#   'model': '500',
#   'modelIdentifier': '500',
#   'modelYear': 2016,
#   'displayVariant': '1.2 S',
#   'mileage': 48716,
#   'registrationYear': 2016,
#   'vrm': 'AP16MKZ',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/ZFA3120000J622838/cd8326a9-f479-4786-8377-ae1da180b87c.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 48716},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/ZFA3120000J622838/cd8326a9-f479-4786-8377-ae1da180b87c.jpg',
#     'car_gallery_images/ZFA3120000J622838/c092d739-e80c-43c8-9635-e04c5475ac63.jpg',
#     'car_gallery_images/ZFA3120000J622838/2091dfef-9ec9-423a-b874-6507dae4c623.jpg',
#     'car_gallery_images/ZFA3120000J622838/4b656de7-bf27-418f-a549-732f8611d12b.jpg',
#     'car_gallery_images/ZFA3120000J622838/e1086c56-52bf-4b63-9602-462e673b0456.jpg',
#     'car_gallery_images/ZFA3120000J622838/dvR1FIXrIk9byCqtaii9.JPG',
#     'car_gallery_images/ZFA3120000J622838/jMmLdFZQ2OSTvXvCLWiF.JPG',
#     'car_gallery_images/ZFA3120000J622838/GWyLmaBorBeNRn54rBcJ.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 770000,
#     'currencyCode': 'GBP',
#     'value': 7700},
#    'pcmPrice': {'hp': {'centAmount': 14549,
#      'currencyCode': 'GBP',
#      'value': 145},
#     'lowest': {'centAmount': 14549,
#      'currencyCode': 'GBP',
#      'value': 145,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-20T14:24:41.118Z',
#   'id': 'f7e55a81-aebf-58e4-b603-74063a226a38',
#   'make': 'Citroen',
#   'makeIdentifier': 'citroen',
#   'model': 'C1',
#   'modelIdentifier': 'c1',
#   'modelYear': 2015,
#   'displayVariant': '1.2 PureTech Flair',
#   'mileage': 45950,
#   'registrationYear': 2016,
#   'vrm': 'FX16LUH',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF7PAHMTCFR774425/d34bc942-b3c9-49a1-9872-0db82ff79b65.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 45950},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF7PAHMTCFR774425/d34bc942-b3c9-49a1-9872-0db82ff79b65.jpg',
#     'car_gallery_images/VF7PAHMTCFR774425/8e77f73b-edcd-4b15-8200-0333f8334c5e.jpg',
#     'car_gallery_images/VF7PAHMTCFR774425/a96244a4-56d9-4955-b1ce-fc55d9a65a3d.jpg',
#     'car_gallery_images/VF7PAHMTCFR774425/a929522a-8b25-4524-a9c3-74650de33baa.jpg',
#     'car_gallery_images/VF7PAHMTCFR774425/a54a304d-8c7b-4a2c-ae5c-170b9e69366d.jpg',
#     'car_gallery_images/VF7PAHMTCFR774425/lgOSX8TK4wbTw0QeMYAh.JPG',
#     'car_gallery_images/VF7PAHMTCFR774425/yzPnGPTsw65k2uKuLk0c.JPG',
#     'car_gallery_images/VF7PAHMTCFR774425/gWo3Emuy4Ii1NHcHmg9P.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 780000,
#     'currencyCode': 'GBP',
#     'value': 7800},
#    'pcmPrice': {'hp': {'centAmount': 14805,
#      'currencyCode': 'GBP',
#      'value': 148},
#     'lowest': {'centAmount': 14805,
#      'currencyCode': 'GBP',
#      'value': 148,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-17T07:53:11.183Z',
#   'id': 'a1245dd9-e834-56cd-b4a6-db1ad4aaa7e8',
#   'make': 'Dacia',
#   'makeIdentifier': 'dacia',
#   'model': 'Sandero',
#   'modelIdentifier': 'sandero',
#   'modelYear': 2017,
#   'displayVariant': '1.0 SCe Ambiance',
#   'mileage': 20488,
#   'registrationYear': 2017,
#   'vrm': 'SA67FHO',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/UU15SDMC558704805/f84c5272-cff0-4232-9649-f6cf244f4207.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 20488},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/UU15SDMC558704805/f84c5272-cff0-4232-9649-f6cf244f4207.jpg',
#     'car_gallery_images/UU15SDMC558704805/28b3172a-de44-4ec1-b1d9-ee1fed300fc4.jpg',
#     'car_gallery_images/UU15SDMC558704805/0d41232f-a19e-4fe5-a9e1-5f70edc29e82.jpg',
#     'car_gallery_images/UU15SDMC558704805/aad6d53d-e321-40c0-80fd-774e7165aa56.jpg',
#     'car_gallery_images/UU15SDMC558704805/0c35de65-72ce-4ab8-bfcf-19c1d7d29fd4.jpg',
#     'car_gallery_images/UU15SDMC558704805/YyAQOpfU6pmvA3l5jJeF.JPG',
#     'car_gallery_images/UU15SDMC558704805/Kw4aklewfRc86bO10cpk.JPG',
#     'car_gallery_images/UU15SDMC558704805/Yal6raGjDC1Nv5wL9uBi.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 780000,
#     'currencyCode': 'GBP',
#     'value': 7800},
#    'pcmPrice': {'hp': {'centAmount': 14805,
#      'currencyCode': 'GBP',
#      'value': 148},
#     'lowest': {'centAmount': 14805,
#      'currencyCode': 'GBP',
#      'value': 148,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-02-14T15:33:55.063Z',
#   'id': '46d1ada1-c1e3-598a-8c7b-0e7ea0148f76',
#   'make': 'Smart',
#   'makeIdentifier': 'smart',
#   'model': 'forfour',
#   'modelIdentifier': 'forfour',
#   'modelYear': 2016,
#   'displayVariant': '1.0 Prime (Premium)',
#   'mileage': 34721,
#   'registrationYear': 2016,
#   'vrm': 'LO16YXB',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/WME4530422Y082968/51c74ae2-132d-456a-9e2c-60008955f329.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 34721},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/WME4530422Y082968/51c74ae2-132d-456a-9e2c-60008955f329.jpg',
#     'car_gallery_images/WME4530422Y082968/4a94d19f-fe6f-4c4a-96f7-b0ca24de399c.jpg',
#     'car_gallery_images/WME4530422Y082968/06c93d9c-3652-41a8-8261-44491cb958a5.jpg',
#     'car_gallery_images/WME4530422Y082968/af52babc-9e10-466f-a2e5-db221375ece9.jpg',
#     'car_gallery_images/WME4530422Y082968/90fb903e-7634-482b-8e45-61ca3616bf32.jpg',
#     'car_gallery_images/WME4530422Y082968/TToaam2mnL26e2tDC75O.JPG',
#     'car_gallery_images/WME4530422Y082968/OX5Mb5gL5Tt0h0QBsIBY.JPG',
#     'car_gallery_images/WME4530422Y082968/SqXPP2fSepH58GMlfqjS.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 780000,
#     'currencyCode': 'GBP',
#     'value': 7800},
#    'pcmPrice': {'hp': {'centAmount': 14805,
#      'currencyCode': 'GBP',
#      'value': 148},
#     'lowest': {'centAmount': 14805,
#      'currencyCode': 'GBP',
#      'value': 148,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-01-19T10:05:26.359Z',
#   'id': '496111c6-52ec-5b9e-b13d-a2cedd944c9d',
#   'make': 'Smart',
#   'makeIdentifier': 'smart',
#   'model': 'fortwo',
#   'modelIdentifier': 'fortwo',
#   'modelYear': 2018,
#   'displayVariant': '0.9T Passion',
#   'mileage': 23577,
#   'registrationYear': 2018,
#   'vrm': 'YM18WPJ',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/WME4533442K293106/fd2a85b0-cf8d-4142-ba2a-cd214b435d40.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 23577},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/WME4533442K293106/fd2a85b0-cf8d-4142-ba2a-cd214b435d40.jpg',
#     'car_gallery_images/WME4533442K293106/60bf7000-696e-4b9c-a6bf-f2b7dd559ae7.jpg',
#     'car_gallery_images/WME4533442K293106/00f8ff9c-318a-4fb5-abd6-019bb8fc8ba0.jpg',
#     'car_gallery_images/WME4533442K293106/e05ae068-0e73-4bc6-bc1a-f6b3df690b4e.jpg',
#     'car_gallery_images/WME4533442K293106/0af19290-fedd-4565-b231-6db28ed3c9f6.jpg',
#     'car_gallery_images/WME4533442K293106/JuMIg5jLQZ5Qegw5mCaY.JPG',
#     'car_gallery_images/WME4533442K293106/vK0FXGSGa5SWodxvKJHz.JPG',
#     'car_gallery_images/WME4533442K293106/L2vKb2sjhJzvACj0bx2R.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 780000,
#     'currencyCode': 'GBP',
#     'value': 7800},
#    'pcmPrice': {'pcp': {'centAmount': 10572,
#      'currencyCode': 'GBP',
#      'value': 106},
#     'hp': {'centAmount': 14805, 'currencyCode': 'GBP', 'value': 148},
#     'lowest': {'centAmount': 10572,
#      'currencyCode': 'GBP',
#      'value': 106,
#      'type': 'pcp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-23T16:31:57.665Z',
#   'id': '13a22491-1d55-5470-954a-623ed5d048c4',
#   'make': 'Nissan',
#   'makeIdentifier': 'nissan',
#   'model': 'Note',
#   'modelIdentifier': 'note',
#   'modelYear': 2015,
#   'displayVariant': '1.2 Acenta Premium',
#   'mileage': 63506,
#   'registrationYear': 2017,
#   'vrm': 'SR66FLD',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/SJNTAAE12U1158935/599fa152-56d4-4ae7-b2e3-ce11259a2e84.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 63506},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/SJNTAAE12U1158935/599fa152-56d4-4ae7-b2e3-ce11259a2e84.jpg',
#     'car_gallery_images/SJNTAAE12U1158935/286bb89e-b8e7-4ee3-94f2-dcc346577037.jpg',
#     'car_gallery_images/SJNTAAE12U1158935/e399a168-c456-4302-8554-4c1f2610f8eb.jpg',
#     'car_gallery_images/SJNTAAE12U1158935/7c8d37e8-ab9d-4e05-88e3-0870a3d8a240.jpg',
#     'car_gallery_images/SJNTAAE12U1158935/fb817021-46ab-453d-8e5c-6d8a0acd7340.jpg',
#     'car_gallery_images/SJNTAAE12U1158935/9zhKwPDCBw0uHMouZPur.JPG',
#     'car_gallery_images/SJNTAAE12U1158935/yJFSoNqP6t2TdiYq2QNb.JPG',
#     'car_gallery_images/SJNTAAE12U1158935/cLRdLzjan7jUVVF9wnZ2.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 790000,
#     'currencyCode': 'GBP',
#     'value': 7900},
#    'pcmPrice': {'hp': {'centAmount': 15060,
#      'currencyCode': 'GBP',
#      'value': 151},
#     'lowest': {'centAmount': 15060,
#      'currencyCode': 'GBP',
#      'value': 151,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-02-27T06:20:03.951Z',
#   'id': '1de233e2-2575-59f6-87bd-ade06795b8ce',
#   'make': 'Dacia',
#   'makeIdentifier': 'dacia',
#   'model': 'Sandero',
#   'modelIdentifier': 'sandero',
#   'modelYear': 2018,
#   'displayVariant': '0.9 TCe Essential',
#   'mileage': 17439,
#   'registrationYear': 2018,
#   'vrm': 'RV68HZZ',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/UU1B5220861223052/c0e804ba-b714-42ea-8dbf-00c375338881.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 17439},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/UU1B5220861223052/c0e804ba-b714-42ea-8dbf-00c375338881.jpg',
#     'car_gallery_images/UU1B5220861223052/0260bc27-a860-4d50-aea4-91db60d8fa2e.jpg',
#     'car_gallery_images/UU1B5220861223052/66338fe7-3cf4-4195-9ad8-90a8360b479d.jpg',
#     'car_gallery_images/UU1B5220861223052/818dd34e-4f45-4ce7-8cd6-4b514de9680d.jpg',
#     'car_gallery_images/UU1B5220861223052/03ec888a-aa6c-474e-ac15-33b8a89104d8.jpg',
#     'car_gallery_images/UU1B5220861223052/Bcil5ETs7yWEjhtxrAFU.JPG',
#     'car_gallery_images/UU1B5220861223052/vLfPbuJSY2Jecb2H5Iug.JPG',
#     'car_gallery_images/UU1B5220861223052/HeExNpxDwqHCfu1u4nOR.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 795000,
#     'currencyCode': 'GBP',
#     'value': 7950},
#    'pcmPrice': {'pcp': {'centAmount': 11845,
#      'currencyCode': 'GBP',
#      'value': 118},
#     'hp': {'centAmount': 15187, 'currencyCode': 'GBP', 'value': 152},
#     'lowest': {'centAmount': 11845,
#      'currencyCode': 'GBP',
#      'value': 118,
#      'type': 'pcp'}}},
#   'isLocked': True},
#  {'createdAt': '2023-01-18T10:29:08.184Z',
#   'id': '7f944a05-a3b7-5bf2-a87d-d47b98cd9bb5',
#   'make': 'Fiat',
#   'makeIdentifier': 'fiat',
#   'model': '500',
#   'modelIdentifier': '500',
#   'modelYear': 2017,
#   'displayVariant': '1.2 S',
#   'mileage': 44135,
#   'registrationYear': 2017,
#   'vrm': 'MC66AYS',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/ZFA3120000J672673/22526624-3138-4fde-b52b-01c7509909f9.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 44135},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/ZFA3120000J672673/22526624-3138-4fde-b52b-01c7509909f9.jpg',
#     'car_gallery_images/ZFA3120000J672673/3b6d8597-da0d-437f-9905-807d7db220be.jpg',
#     'car_gallery_images/ZFA3120000J672673/f0b946c7-7f5d-4f97-87ac-70d5dd7d79e7.jpg',
#     'car_gallery_images/ZFA3120000J672673/62870fa0-d352-4053-aac8-1ce8ca233bfb.jpg',
#     'car_gallery_images/ZFA3120000J672673/7693fbbf-c7e0-4863-827c-ce32001737c8.jpg',
#     'car_gallery_images/ZFA3120000J672673/qqO0QpMcDRLHkctqJVWc.JPG',
#     'car_gallery_images/ZFA3120000J672673/PjcDhD7F1Napl9mkFrqw.JPG',
#     'car_gallery_images/ZFA3120000J672673/5coW0qMlnXAuQG9tIpMs.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 795000,
#     'currencyCode': 'GBP',
#     'value': 7950},
#    'pcmPrice': {'hp': {'centAmount': 15187,
#      'currencyCode': 'GBP',
#      'value': 152},
#     'lowest': {'centAmount': 15187,
#      'currencyCode': 'GBP',
#      'value': 152,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-12T10:21:56.805Z',
#   'id': 'd7515621-2b68-5f83-8279-6c08fbf52794',
#   'make': 'Hyundai',
#   'makeIdentifier': 'hyundai',
#   'model': 'i10',
#   'modelIdentifier': 'i10',
#   'modelYear': 2017,
#   'displayVariant': '1.0 SE',
#   'mileage': 39166,
#   'registrationYear': 2017,
#   'vrm': 'NU67WNT',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/NLHA851ALJZ376672/fcf280ac-569a-48d6-8485-6f349cf708e9.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 39166},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/NLHA851ALJZ376672/fcf280ac-569a-48d6-8485-6f349cf708e9.jpg',
#     'car_gallery_images/NLHA851ALJZ376672/a676f162-224b-430d-812a-f9e294261b72.jpg',
#     'car_gallery_images/NLHA851ALJZ376672/43c9d3de-9717-44d2-8c9f-828ed74fe86e.jpg',
#     'car_gallery_images/NLHA851ALJZ376672/c6bb508b-978d-4573-b1d3-9eedf5d23652.jpg',
#     'car_gallery_images/NLHA851ALJZ376672/73dfef75-9a60-4c40-977c-caff7639ca81.jpg',
#     'car_gallery_images/NLHA851ALJZ376672/5sQ4YGPhUyVSdNXnoRTw.JPG',
#     'car_gallery_images/NLHA851ALJZ376672/clODX6V18FLo3HlXQexz.JPG',
#     'car_gallery_images/NLHA851ALJZ376672/jb24IUcyPTWrcbhUNulH.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 800000,
#     'currencyCode': 'GBP',
#     'value': 8000},
#    'pcmPrice': {'hp': {'centAmount': 15315,
#      'currencyCode': 'GBP',
#      'value': 153},
#     'lowest': {'centAmount': 15315,
#      'currencyCode': 'GBP',
#      'value': 153,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-02-22T15:16:34.683Z',
#   'id': '33e9051b-0d38-5356-ba22-a44bd940b1ad',
#   'make': 'Renault',
#   'makeIdentifier': 'renault',
#   'model': 'Zoe',
#   'modelIdentifier': 'zoe',
#   'modelYear': 2013,
#   'displayVariant': '22kWh Dynamique Nav Auto',
#   'mileage': 44917,
#   'registrationYear': 2015,
#   'vrm': 'LC65HZW',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Electric',
#    'isEcoFriendly': True,
#    'isPlugin': True},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF1AGVYB054464910/488686cb-4c25-4102-9f8f-9a79dc7d6628.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 44917},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Automatic',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF1AGVYB054464910/488686cb-4c25-4102-9f8f-9a79dc7d6628.jpg',
#     'car_gallery_images/VF1AGVYB054464910/d51de9e4-f594-4b87-bdb1-e60c54c3c468.jpg',
#     'car_gallery_images/VF1AGVYB054464910/b6d63eb2-0665-4187-90b4-36def31e393c.jpg',
#     'car_gallery_images/VF1AGVYB054464910/e70dd048-5631-4574-84b5-69d9602aa2c4.jpg',
#     'car_gallery_images/VF1AGVYB054464910/b3910391-7fbf-495e-9c80-d28c247e19a0.jpg',
#     'car_gallery_images/VF1AGVYB054464910/jSE2UgPVcVWG0r8dmNRN.JPG',
#     'car_gallery_images/VF1AGVYB054464910/bQ6LYr49whcsHmJki2KP.JPG',
#     'car_gallery_images/VF1AGVYB054464910/tLEO4HunFsCOyggMylKC.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 800000,
#     'currencyCode': 'GBP',
#     'value': 8000},
#    'pcmPrice': {'hp': {'centAmount': 15315,
#      'currencyCode': 'GBP',
#      'value': 153},
#     'lowest': {'centAmount': 15315,
#      'currencyCode': 'GBP',
#      'value': 153,
#      'type': 'hp'}}},
#   'isLocked': True},
#  {'createdAt': '2022-12-27T18:34:54.202Z',
#   'id': '26dabd43-f40a-5439-80f8-a79caeae4c4f',
#   'make': 'Fiat',
#   'makeIdentifier': 'fiat',
#   'model': '500',
#   'modelIdentifier': '500',
#   'modelYear': 2014,
#   'displayVariant': '1.2 S',
#   'mileage': 24132,
#   'registrationYear': 2017,
#   'vrm': 'YR67WTN',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
# ...
#     'car_gallery_images/WF0BXXMRKBGR58290/379db47a-a024-476e-906b-a9ab47963a0a.jpg',
#     'car_gallery_images/WF0BXXMRKBGR58290/24840f92-7971-4714-a1f3-9fc613049c42.jpg',
#     'car_gallery_images/WF0BXXMRKBGR58290/Ta04y6foj7t6MIjbG1Sg.JPG',
#     'car_gallery_images/WF0BXXMRKBGR58290/Y6m69TfCQJfvf0Uy845W.JPG',
#     'car_gallery_images/WF0BXXMRKBGR58290/ojVjbZyZrBxeOOksAH8I.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 840000,
#     'currencyCode': 'GBP',
#     'value': 8400},
#    'priceBeforePromotion': {'centAmount': 860000,
#     'currencyCode': 'GBP',
#     'value': 8600},
#    'pcmPrice': {'hp': {'centAmount': 16336,
#      'currencyCode': 'GBP',
#      'value': 163},
#     'lowest': {'centAmount': 16336,
#      'currencyCode': 'GBP',
#      'value': 163,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2022-09-03T12:55:02.151Z',
#   'id': '3d4c0fb9-4661-50e1-ad04-36689d014bbf',
#   'make': 'Ssangyong',
#   'makeIdentifier': 'ssangyong',
#   'model': 'Tivoli',
#   'modelIdentifier': 'tivoli',
#   'modelYear': 2016,
#   'displayVariant': '1.6 e-XDi ELX',
#   'mileage': 68569,
#   'registrationYear': 2016,
#   'vrm': 'AY16XEE',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Diesel',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/KPT30B1USFP041450/mY9ezgubDcXjcqTg8OqF.JPG'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 68569},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/KPT30B1USFP041450/mY9ezgubDcXjcqTg8OqF.JPG',
#     'car_gallery_images/KPT30B1USFP041450/rCA35gi9Vbn1m9hMRMpw.JPG',
#     'car_gallery_images/KPT30B1USFP041450/3C1PseG2106LUEtxp1p3.JPG',
#     'car_gallery_images/KPT30B1USFP041450/PsSzsev66Dx9K82YDXCQ.JPG',
#     'car_gallery_images/KPT30B1USFP041450/NKPcUwWdEytT3YhHRXjw.JPG',
#     'car_gallery_images/KPT30B1USFP041450/n0ClAaHRD5klpyHUd98M.JPG',
#     'car_gallery_images/KPT30B1USFP041450/NVGryCd9LrxvMLcpM2Zt.JPG',
#     'car_gallery_images/KPT30B1USFP041450/SzN7G2bVylD6bIWoOB6s.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 840000,
#     'currencyCode': 'GBP',
#     'value': 8400},
#    'pcmPrice': {'hp': {'centAmount': 16336,
#      'currencyCode': 'GBP',
#      'value': 163},
#     'lowest': {'centAmount': 16336,
#      'currencyCode': 'GBP',
#      'value': 163,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-26T15:45:57.809Z',
#   'id': '5fe09697-57bf-5d75-9ce3-a1ced2a50ec2',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'ADAM',
#   'modelIdentifier': 'adam',
#   'modelYear': 2017,
#   'displayVariant': '1.2i ecoFLEX ENERGISED',
#   'mileage': 58963,
#   'registrationYear': 2017,
#   'vrm': 'DY17WLX',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0L0MAP08H6070948/3bf73e09-5d0a-4354-b9cf-3cde6c2e5481.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 58963},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0L0MAP08H6070948/3bf73e09-5d0a-4354-b9cf-3cde6c2e5481.jpg',
#     'car_gallery_images/W0L0MAP08H6070948/232f6dda-c70c-44bc-998e-a2c1e0cc6e22.jpg',
#     'car_gallery_images/W0L0MAP08H6070948/8ef2b6b8-9b50-4bf8-bdad-d75d4cbfc075.jpg',
#     'car_gallery_images/W0L0MAP08H6070948/519d3f3b-8db1-48b3-a033-01352d24dbbd.jpg',
#     'car_gallery_images/W0L0MAP08H6070948/b7e06322-3954-4473-ad6f-7db814da1ea7.jpg',
#     'car_gallery_images/W0L0MAP08H6070948/AVSIPaEFDs42VqKEktOg.JPG',
#     'car_gallery_images/W0L0MAP08H6070948/sfVmSrt8riBacloHtaid.JPG',
#     'car_gallery_images/W0L0MAP08H6070948/4cexUHkYqcIqQLpNWruT.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 845000,
#     'currencyCode': 'GBP',
#     'value': 8450},
#    'pcmPrice': {'hp': {'centAmount': 16464,
#      'currencyCode': 'GBP',
#      'value': 165},
#     'lowest': {'centAmount': 16464,
#      'currencyCode': 'GBP',
#      'value': 165,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2022-12-22T15:17:51.495Z',
#   'id': '3d0a9a7c-3282-5f67-ac8e-b149afefe8ae',
#   'make': 'Fiat',
#   'makeIdentifier': 'fiat',
#   'model': '500',
#   'modelIdentifier': '500',
#   'modelYear': 2017,
#   'displayVariant': '1.2 Lounge',
#   'mileage': 35041,
#   'registrationYear': 2019,
#   'vrm': 'WN69TOV',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/ZFA3120000JC69198/cf24b15e-6d30-42b3-9d5a-79aac164332a.jpg'}},
#   'isPromoted': True,
#   'odometerReading': {'unit': 'mile', 'value': 35041},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/ZFA3120000JC69198/cf24b15e-6d30-42b3-9d5a-79aac164332a.jpg',
#     'car_gallery_images/ZFA3120000JC69198/51b034a4-3e6e-4868-a7f6-9b3b3638a712.jpg',
#     'car_gallery_images/ZFA3120000JC69198/7e7ffd88-409a-44cb-9da7-28489aef2c91.jpg',
#     'car_gallery_images/ZFA3120000JC69198/d8a606d5-c8a6-45c2-bd39-4ddf7ab57c05.jpg',
#     'car_gallery_images/ZFA3120000JC69198/b20b7512-3e0f-4ea6-ada7-d3f508b11c28.jpg',
#     'car_gallery_images/ZFA3120000JC69198/0CFC9ceHpJap6RRvzeci.JPG',
#     'car_gallery_images/ZFA3120000JC69198/E26HA93X0lSGxgM5HWJZ.JPG',
#     'car_gallery_images/ZFA3120000JC69198/XGFYWQZFq912Wr8DzMX4.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 845000,
#     'currencyCode': 'GBP',
#     'value': 8450},
#    'priceBeforePromotion': {'centAmount': 865000,
#     'currencyCode': 'GBP',
#     'value': 8650},
#    'pcmPrice': {'pcp': {'centAmount': 10634,
#      'currencyCode': 'GBP',
#      'value': 106},
#     'hp': {'centAmount': 16464, 'currencyCode': 'GBP', 'value': 165},
#     'lowest': {'centAmount': 10634,
#      'currencyCode': 'GBP',
#      'value': 106,
#      'type': 'pcp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-16T17:51:51.668Z',
#   'id': '43a070d5-e068-5441-b7f8-19ac97d237ff',
#   'make': 'Nissan',
#   'makeIdentifier': 'nissan',
#   'model': 'Note',
#   'modelIdentifier': 'note',
#   'modelYear': 2012,
#   'displayVariant': '1.5 dCi Tekna',
#   'mileage': 45717,
#   'registrationYear': 2016,
#   'vrm': 'WJ66WHN',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Diesel',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/SJNTCAE12U1178822/8dd52682-f51c-4cf7-8bbd-02b203a85348.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 45717},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/SJNTCAE12U1178822/8dd52682-f51c-4cf7-8bbd-02b203a85348.jpg',
#     'car_gallery_images/SJNTCAE12U1178822/387f0324-4024-465f-9b58-fd02ffc9d440.jpg',
#     'car_gallery_images/SJNTCAE12U1178822/2a530b91-ddf2-49d9-88d4-a06bce73a481.jpg',
#     'car_gallery_images/SJNTCAE12U1178822/5baa57cc-33cf-4c2a-b8c7-1cce0f726409.jpg',
#     'car_gallery_images/SJNTCAE12U1178822/27a4870c-f6f7-411c-b6e2-a81d3c4665de.jpg',
#     'car_gallery_images/SJNTCAE12U1178822/It8McHKdkKIAqu3TSd12.JPG',
#     'car_gallery_images/SJNTCAE12U1178822/BDl1cP7j1mlfwftQdb0A.JPG',
#     'car_gallery_images/SJNTCAE12U1178822/Ejal1mndc2qnvFfCMBAU.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 850000,
#     'currencyCode': 'GBP',
#     'value': 8500},
#    'pcmPrice': {'hp': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166},
#     'lowest': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-03-02T08:57:57.837Z',
#   'id': '7f374d52-eeed-5fb5-af1c-f26aafac1577',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'Viva',
#   'modelIdentifier': 'viva',
#   'modelYear': 2019,
#   'displayVariant': '1.0i SE',
#   'mileage': 29499,
#   'registrationYear': 2018,
#   'vrm': 'CV18NME',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0VDD6E75JC444284/70eb07ed-7872-4d35-9fcd-a40a1091585a.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 29499},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0VDD6E75JC444284/70eb07ed-7872-4d35-9fcd-a40a1091585a.jpg',
#     'car_gallery_images/W0VDD6E75JC444284/9ab7ec1f-1677-4b7f-b018-16c3ece8bc24.jpg',
#     'car_gallery_images/W0VDD6E75JC444284/93802d92-e153-4370-890f-e3502a653d0a.jpg',
#     'car_gallery_images/W0VDD6E75JC444284/b7e37b18-7aa6-441c-a7e1-4eef1002d327.jpg',
#     'car_gallery_images/W0VDD6E75JC444284/cd146d3d-7acf-4477-a690-99ac0b5efd29.jpg',
#     'car_gallery_images/W0VDD6E75JC444284/P9UjFPmWT98g5dWJRfLh.JPG',
#     'car_gallery_images/W0VDD6E75JC444284/aIBInmDNOpOKGVS0G3Wc.JPG',
#     'car_gallery_images/W0VDD6E75JC444284/lsVS9MyehRCcntzWpyhI.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 850000,
#     'currencyCode': 'GBP',
#     'value': 8500},
#    'pcmPrice': {'pcp': {'centAmount': 13283,
#      'currencyCode': 'GBP',
#      'value': 133},
#     'hp': {'centAmount': 16591, 'currencyCode': 'GBP', 'value': 166},
#     'lowest': {'centAmount': 13283,
#      'currencyCode': 'GBP',
#      'value': 133,
#      'type': 'pcp'}}},
#   'isLocked': False},
#  {'createdAt': '2023-02-28T09:52:54.378Z',
#   'id': '77110a58-cdf7-5384-a5f3-6c2f4a9c617c',
#   'make': 'Vauxhall',
#   'makeIdentifier': 'vauxhall',
#   'model': 'ADAM',
#   'modelIdentifier': 'adam',
#   'modelYear': 2017,
#   'displayVariant': '1.2i GLAM',
#   'mileage': 35129,
#   'registrationYear': 2017,
#   'vrm': 'FH66KVC',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Petrol',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/W0L0MAP08G6117036/03a9b319-ea47-496f-b53a-3b6ad2ced06f.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 35129},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/W0L0MAP08G6117036/03a9b319-ea47-496f-b53a-3b6ad2ced06f.jpg',
#     'car_gallery_images/W0L0MAP08G6117036/c76441e6-d1be-49f1-b9cd-e3c61092f4bb.jpg',
#     'car_gallery_images/W0L0MAP08G6117036/6134dae8-6bd4-45ae-9a46-bb76b8485798.jpg',
#     'car_gallery_images/W0L0MAP08G6117036/1569a3c8-c89e-4087-afe0-b8098a9c70c9.jpg',
#     'car_gallery_images/W0L0MAP08G6117036/0a56ee3b-d9af-425a-8b2b-943ffc61844e.jpg',
#     'car_gallery_images/W0L0MAP08G6117036/2bB3eNDGj3rFmX9TG9XC.JPG',
#     'car_gallery_images/W0L0MAP08G6117036/EkWRjOBqd0eMDiybejwN.JPG',
#     'car_gallery_images/W0L0MAP08G6117036/Fm9VEkIqzA11dhhCOTeZ.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 850000,
#     'currencyCode': 'GBP',
#     'value': 8500},
#    'pcmPrice': {'hp': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166},
#     'lowest': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166,
#      'type': 'hp'}}},
#   'isLocked': False},
#  {'createdAt': '2022-12-20T16:14:16.778Z',
#   'id': '629fd988-1593-58ca-a180-5db6c32ecbe9',
#   'make': 'Nissan',
#   'makeIdentifier': 'nissan',
#   'model': 'Juke',
#   'modelIdentifier': 'juke',
#   'modelYear': 2014,
#   'displayVariant': '1.5 dCi Visia',
#   'mileage': 43517,
#   'registrationYear': 2017,
#   'vrm': 'BF66YYX',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Diesel',
#    'isEcoFriendly': False,
#    'isPlugin': False},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/SJNFCAF15U7273683/bcbc5c5b-cc24-481a-b09c-ce5b2525d6c3.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 43517},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Manual',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/SJNFCAF15U7273683/bcbc5c5b-cc24-481a-b09c-ce5b2525d6c3.jpg',
#     'car_gallery_images/SJNFCAF15U7273683/67e2b8b4-db0b-4f28-807b-fed7d067ffe7.jpg',
#     'car_gallery_images/SJNFCAF15U7273683/b21e16d7-a059-4f2a-9328-99151f1d91a0.jpg',
#     'car_gallery_images/SJNFCAF15U7273683/32f41178-37c6-4ecc-8b66-5b3ee9748108.jpg',
#     'car_gallery_images/SJNFCAF15U7273683/6dd6378c-1bd6-4081-8249-daf9cecf77a2.jpg',
#     'car_gallery_images/SJNFCAF15U7273683/zAkEM2Lg5qecB7jv3jP4.JPG',
#     'car_gallery_images/SJNFCAF15U7273683/iNb2VrFBANDApJcqpTB8.JPG',
#     'car_gallery_images/SJNFCAF15U7273683/3M3PNWc5W1OxjJNaFib7.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 850000,
#     'currencyCode': 'GBP',
#     'value': 8500},
#    'pcmPrice': {'hp': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166},
#     'lowest': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166,
#      'type': 'hp'}}},
#   'isLocked': True},
#  {'createdAt': '2022-11-23T09:24:41.791Z',
#   'id': '4d377702-e974-5e15-a49c-280eed977d00',
#   'make': 'Renault',
#   'makeIdentifier': 'renault',
#   'model': 'Zoe',
#   'modelIdentifier': 'zoe',
#   'modelYear': 2013,
#   'displayVariant': '22kWh Dynamique Nav Auto',
#   'mileage': 27746,
#   'registrationYear': 2016,
#   'vrm': 'WJ16ACY',
#   'isForSubscription': False,
#   'isForPurchase': True,
#   'fuelType': {'description': 'Electric',
#    'isEcoFriendly': True,
#    'isPlugin': True},
#   'images': {'main': {'url': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/VF1AGVYB054991917/135b03f9-b179-498f-baa7-79b7eea6a863.jpg'}},
#   'isPromoted': False,
#   'odometerReading': {'unit': 'mile', 'value': 27746},
#   'tradingMarket': 'gb',
#   'vehicleType': 'Car',
#   'gearbox': 'Automatic',
#   'gallery': {'prefix': 'https://media.cazoo.com/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/',
#    'items': ['car_gallery_images/VF1AGVYB054991917/135b03f9-b179-498f-baa7-79b7eea6a863.jpg',
#     'car_gallery_images/VF1AGVYB054991917/569abb64-9bdf-4778-83a2-5b2554058a48.jpg',
#     'car_gallery_images/VF1AGVYB054991917/ba58e6dd-18da-436a-bbb4-88df1f6b4282.jpg',
#     'car_gallery_images/VF1AGVYB054991917/52f5b82f-d772-4ab9-88bb-b9c2ee4318c3.jpg',
#     'car_gallery_images/VF1AGVYB054991917/a8645054-4c64-401e-98e9-40901951f1fd.jpg',
#     'car_gallery_images/VF1AGVYB054991917/2Y1HhS661RgjAkUCGLVn.JPG',
#     'car_gallery_images/VF1AGVYB054991917/u3tpLkbvNgmupzqTBvYD.JPG',
#     'car_gallery_images/VF1AGVYB054991917/RoL6GWLZswjLR27JuK4D.JPG']},
#   'pricing': {'fullPrice': {'centAmount': 850000,
#     'currencyCode': 'GBP',
#     'value': 8500},
#    'pcmPrice': {'hp': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166},
#     'lowest': {'centAmount': 16591,
#      'currencyCode': 'GBP',
#      'value': 166,
#      'type': 'hp'}}},
#   'isLocked': False}]

# %% [markdown]
# #### 6 - Trouvez vos données
# - marque
# - modèle
# - type de carburant
# - Kilométrage
# - année du modèle
# - prix

# %%
# brand
listing[0]['make']
# Out:
# 'Kia'

# %%
# model
listing[0]['model']
# Out:
# 'Picanto'

# %%
# fuel type
listing[0]['fuelType']['description']
# Out:
# 'Petrol'

# %%
#miles
listing[0]['mileage']
# Out:
# 36057

# %%
# model year
listing[0]['modelYear']
# Out:
# 2015

# %%
# price

listing[0]['pricing']['fullPrice']['centAmount']
# Out:
# 655000

# %% [markdown]
# #### 7 - Mettre tout ensemble - Boucler les résultats et ajouter des données dans une liste

# %%
# empty lists
brand = []
model = []
fuel_type = []
miles = []
model_year = []
price = []

for result in listing:
    
    # brand
    brand.append(result['make'])
    
    # model 
    model.append(result['model'])
    # fuel type
    fuel_type.append(result['fuelType']['description'])
    
    # miles
    miles.append(result['mileage'])
    
    #model year
    model_year.append(result['modelYear'])
    # price
    price.append(result['pricing']['fullPrice']['centAmount'])

# %% [markdown]
# #### 8 - Pandas Dataframe - Single Page

# %%
car_df = pd.DataFrame({'Brand': brand, 'Model':model, 'Fuel Type': fuel_type, 'Mileage':miles,
                      'Model Year': model_year, 'Price':price})

# %%
car_df
# Out:
#         Brand     Model Fuel Type  Mileage  Model Year   Price
# 0         Kia   Picanto    Petrol    36057        2015  655000
# 1     Peugeot       108    Petrol    35847        2016  680000
# 2     Peugeot       108    Petrol    62681        2016  690000
# 3     Peugeot       108    Petrol    43773        2015  690000
# 4        Fiat       500    Petrol    41216        2015  700000
# 5    Vauxhall     Corsa    Petrol    30278        2017  720000
# 6        Fiat       500    Petrol    35534        2015  740000
# 7    Vauxhall     Corsa    Petrol    54681        2016  740000
# 8    Vauxhall      ADAM    Petrol    36676        2017  740000
# 9      Toyota      AYGO    Petrol    56845        2017  745000
# 10   Vauxhall      Viva    Petrol     9664        2017  745000
# 11         DS      DS 3    Diesel    54023        2015  755000
# 12     Toyota      AYGO    Petrol    32725        2016  765000
# 13      Skoda    Citigo    Petrol    25428        2018  765000
# 14      Dacia   Sandero    Petrol    24080        2017  770000
# 15       Fiat       500    Petrol    48716        2016  770000
# 16    Citroen        C1    Petrol    45950        2015  780000
# 17      Dacia   Sandero    Petrol    20488        2017  780000
# 18      Smart   forfour    Petrol    34721        2016  780000
# 19      Smart    fortwo    Petrol    23577        2018  780000
# 20     Nissan      Note    Petrol    63506        2015  790000
# 21      Dacia   Sandero    Petrol    17439        2018  795000
# 22       Fiat       500    Petrol    44135        2017  795000
# 23    Hyundai       i10    Petrol    39166        2017  800000
# 24    Renault       Zoe  Electric    44917        2013  800000
# 25       Fiat       500    Petrol    24132        2014  800000
# 26        Kia     Venga    Diesel    39530        2015  805000
# 27     Toyota      AYGO    Petrol    24621        2015  810000
# 28     Toyota      AYGO    Petrol    37004        2017  810000
# 29    Citroen        C1    Petrol    37443        2016  820000
# 30      Dacia   Sandero    Petrol    25405        2018  820000
# 31    Citroen        C1    Petrol    12874        2017  830000
# 32      Skoda    Citigo    Petrol    23603        2018  830000
# 33    Peugeot       208    Petrol    42029        2016  830000
# 34     Nissan      Leaf  Electric    22148        2015  830000
# 35      Dacia   Sandero    Petrol     6518        2019  835000
# 36       Fiat       500    Petrol    49040        2017  840000
# 37       Fiat       500    Petrol    41851        2015  840000
# 38    Hyundai       i10    Petrol    21309        2014  840000
# 39       Ford  EcoSport    Petrol    26814        2015  840000
# 40  Ssangyong    Tivoli    Diesel    68569        2016  840000
# 41   Vauxhall      ADAM    Petrol    58963        2017  845000
# 42       Fiat       500    Petrol    35041        2017  845000
# 43     Nissan      Note    Diesel    45717        2012  850000
# 44   Vauxhall      Viva    Petrol    29499        2019  850000
# 45   Vauxhall      ADAM    Petrol    35129        2017  850000
# 46     Nissan      Juke    Diesel    43517        2014  850000
# 47    Renault       Zoe  Electric    27746        2013  850000

# %%
car_df.to_csv('data.csv')

# %% [markdown]
# #### 9 - Scraping Plusieurs Pages (ici : 20 pages)

# %%
headers = {
    'authority': 'www.cazoo.co.uk',
    'sec-ch-ua': '^\\^',
    'cazoo-language': 'en',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'cazoo-market': 'gb',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.cazoo.co.uk/cars/',
    'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
    'cookie': 'base_device_id=d0a0a3f4-6853-469a-920f-6050e04a23d0; base_session_count=1',
}

# empty lists
brand = []
model = []
fuel_type = []
miles = []
model_year = []
price = []

for i in range(1,21):

    params = (
        ('page', str(i)),
        ('sort', 'price-asc'),
    )

    response = requests.get('https://www.cazoo.co.uk/api/search', headers=headers, params=params)

    results_json = response.json()
    
    listing = results_json['results']
    
    for result in listing:
    
        # brand
        try:
            brand.append(result['make'])
        except:
            brand.append('')

        # model 
        try:
            model.append(result['model'])
        except:
            model.append('')

        # fuel type
        try:
            fuel_type.append(result['fuelType']['description'])
        except:
            fuel_type.append('')

        # miles
        try:
            miles.append(result['mileage'])
        except:
            miles.append('')

        #model year
        try:
            model_year.append(result['modelYear'])
        except:
            model_year

        # price
        try:
            price.append(result['pricing']['fullPrice']['value'])
        except:
            price.append('')
        

car_df_multiple = pd.DataFrame({'Brand': brand, 'Model':model, 'Fuel Type': fuel_type, 'Mileage':miles,
                      'Model Year': model_year, 'Price':price})   

car_df_multiple
# Out:
#         Brand     Model Fuel Type  Mileage  Model Year  Price
# 0         Kia   Picanto    Petrol    36057        2015   6550
# 1     Peugeot       108    Petrol    35847        2016   6800
# 2     Peugeot       108    Petrol    62681        2016   6900
# 3     Peugeot       108    Petrol    43773        2015   6900
# 4        Fiat       500    Petrol    41216        2015   7000
# ..        ...       ...       ...      ...         ...    ...
# 955      Mini     Hatch    Petrol    21190        2016  13200
# 956       BMW  1 Series    Diesel    42566        2016  13200
# 957  Vauxhall   Mokka X    Petrol    28187        2018  13200
# 958   Peugeot       308    Petrol    25991        2021  13200
# 959  Vauxhall     Astra    Petrol     5808        2017  13200
#
# [960 rows x 6 columns]

# %%
car_df_multiple.to_csv('data_multiple.csv')
